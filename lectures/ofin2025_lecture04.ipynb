# %% [markdown]
# <center>
# <img src="../images/fscampus_small2.png" width="1200"/>
# </center>
#
#
# ***Finance I (OFIN)-SS2025***
#
# **Dr. Omer Cayirli**
#
# Lecturer in Empirical Finance
#
# omer.cayirli@vgu.edu.vn
#
# ---

# %% [markdown]
# ## Lecture 04
# ---

# %% [markdown]
# ### Outline
# #### Fundamentals of capital budgeting
# *   Forecasting Earnings
# *   Free Cash Flow and NPV
# *   Analyzing Projects and Choosing among Alternatives
# ---

# %% [markdown]
# ### Capital Budgeting
#
# **Capital Budget**
# *   Lists the investments that a company plans to undertake.
#
# **Capital Budgeting**
# *   Process used to analyze alternative investments.
# *   Ultimate goal is to determine the effect of the decision on the firm's cash flows.
#
# **Incremental Earnings**
# *   The amount by which the firm's earnings are expected to change as a result of the investment decision.
#
# **Capital Budgeting Process**
# *   Revenue and cost estimates
# *   Incremental earnings forecast
# *   Free cash flow and NPV
# *   Choose among alternatives
#
# ---

# %% [markdown]
# ### Capital Budgeting
#
# * Discount cash flows, not profits.
#
# * Discount incremental cash flows.
#
# * Treat inflation consistently.
#
# * Separate investment and financing decisions.
#
# * Forecast and deduct taxes.
#
# ---

# %% [markdown]
# ### Capital Budgeting: Discount cash flows, not profits
#
# *   Accounting earnings are often different from actual cash flows! Always discount **cash flows**, not accounting profits.
#
# *   It costs **\$5,000** upfront (Year 0) and is expected to generate cash revenues of **\$3,500** in Year 1 and **\$2,500** in Year 2. The accountant depreciates the initial development cost straight-line over the two years.
#
#     |                     | Year 1   | Year 2   |
#     | :------------------ | :------- | :------- |
#     | Cash inflow         | +$3,500  | +$2,500  |
#     | Less depreciation   | - 2,500  | - 2,500  |
#     | Accounting Income | +$1,000| $0   |
#
#     *   If we mistakenly discount *accounting income* at a 12% cost of capital:
#     $$ NPV = \frac{\$1,000}{1.12^1} + \frac{\$0}{1.12^2} = \$892.86 \ \ \ \mathbf{<-- WRONG!} $$
#
#     *   Instead, we must discount the actual *cash flows*:
#     $$ NPV = -\$5,000 + \frac{\$3,500}{1.12^1} + \frac{\$2,500}{1.12^2} $$
#     $$ NPV = -\$5,000 + \$3,125.00 + \$1,992.98 = \mathbf{\$117.98 \ \ \ <-- CORRECT!} $$
#
# ---

# %% [markdown]
# ### Capital Budgeting: Working capital matters
#
# *   Changes in working capital affect the *timing* of cash flows and can differ significantly from when income is recognized.
#
# *   A consulting project requires paying specialist fees of **\$8,000** at (t=1). The client is billed **\$15,000** upon project completion (t=1) and pays at t=2.
#
#     **Accounting perspective (assuming income recognized when billed):**
#     |                     | Amount(\$)  | Timing |
#     | :------------------ | ------: | -----: |
#     | Revenue             | 15,000 | t=1    |
#     | Less cost           | - 8,000 | t=1    |
#     | Accounting Income | $ 7,000 | t=1|
#
#     **Cash Flow perspective:**
#     |                            | t=0 | t=1 | t=2 |
#     | :------------------------- | -------: | -------: | -------: |
#     | **Components of CF:**      |          |          |          |
#     | Cash Outlay (Specialists)  |      0   | -8,000   |       0  |
#     | Cash Inflow (Client Pmt)   |      0   |      0   | +15,000  |
#     | Net Cash flow              |      0   | -8,000   | +15,000  |
#
#
# * The timing difference between cash flow and accounting income can significantly impact project valuation.
# * **Always track the actual cash inflows and outflows.**
#
# ---

# %% [markdown]
# ### Capital Budgeting: Discount incremental cash flows
#
# *   The value of a project depends on all the additional cash flows that follow from project acceptance.
# *   Include all incidental effects
#     *   Introduction of a new product will almost certainly cut into sales of existing products (Product Cannibalization).
# *   Do not confuse average with incremental payoffs
#     *   The incremental NPV from investing in a loser may be strongly positive.
#     *   Also, it does not always make sense to throw good money after good.
# *   Forecast product sales but also recognize after-sales cash flows.
# *   Include opportunity costs.
# *   Forget sunk costs.
#     *   They are past and irreversible outflows.
# *   Beware of allocated overhead costs.
#     *   In investment appraisal we should include only the extra expenses that would result from the project.
# *   Remember salvage value
#     *   When the project comes to an end, you may be able to sell the plant and equipment or redeploy the assets elsewhere in the business.
#
# ---

# %% [markdown]
# ### Capital Budgeting: Discount incremental cash flows
#
# *   GreenSpark Energy, a manufacturer of residential solar panels, is considering introducing a next-generation, higher-efficiency panel. The firm anticipates that annual sales of the new panel will be $50 million. While many sales will attract new customers, GreenSpark estimates that 30% will come from existing customers who opt for the new panel instead of the current model.
#
#     *   Assume customers spend roughly the same amount on either panel model. What level of *incremental sales* is associated with introducing the new high-efficiency panel?
#
#         *Incremental Sales = Total New Product Sales * (1 - Cannibalization Rate)*
#
#         *Incremental Sales = $\$50$ million * (1 – 30%) = $\$50$ million * 0.70 = $\$35$ million*
#
#
#     *   Now, suppose GreenSpark's market research indicates that 60% of the customers who would potentially switch from the original panel to the new one *would likely switch to a competitor's high-efficiency panel* if GreenSpark doesn't launch its own new model. What is the level of incremental sales in this case?
#
#     *Incremental Sales = Total Sales * (1 - Cannibalization Rate + Lost Sales Avoided)*
#
#     $\qquad \qquad \qquad \; \; \; = \$50m * (1 - 30\% + 18\%) = \$50m * 88\% = \$44 \text{million}$
#
#     *Incremental Sales = Total New Product Sales * (1 – (Original Cannibalization Rate * % Staying Customers))*
#
#
#     *Incremental Sales = $\$50m$ * [(1 – (30% * (1 - 60%))] = $\$44$ million*
#
# ---

# %% [markdown]
# ### Capital Budgeting: Discount incremental cash flows
#
# CloudSync Solutions is considering launching a significant marketing campaign for its new "TeamFlow" collaboration software. CloudSync plans to spend $\$3$ million on digital advertising and content marketing this year. The campaign is expected to boost TeamFlow sales by $\$6$ million this year and $\$4$ million next year. Additionally, the company anticipates that increased brand visibility will drive adoption of its other cloud storage products, increasing sales of those by $\$1.5$ million each year for the next two years. CloudSync's gross profit margin for TeamFlow is 65%, and its average gross profit margin is 30% for its other products. The company's marginal corporate tax rate is 25% for both years. What are the incremental earnings associated with this marketing campaign?
#
# #### Incremental Earnings Calculation ($ millions)
# |                                      | Year 1    | Year 2    |
# | :----------------------------------- | --------: | --------: |
# | Incremental Sales                    |           |           |
# |   TeamFlow Software                  | 6.00      | 4.00      |
# |   Other Cloud Products               | 1.50      | 1.50      |
# | Total Incremental Sales              | 7.50      | 5.50      |
# | Cost of Goods Sold (COGS)            |           |           |
# |   TeamFlow (Sales * (1 - 0.65))      | 2.10      | 1.40      |
# |   Other Products (Sales * (1 - 0.30))| 1.05      | 1.05      |
# | Total COGS                           | 3.15      | 2.45      |
# | Gross Profit                         | 4.35      | 3.05      |
# | Selling, General & Admin (SG&A)      |           |           |
# |   Marketing Campaign Cost            | 3.00      | 0.00      |
# | Earnings Before Interest & Tax (EBIT)| 1.35      | 3.05      |
# | Taxes (EBIT * 25%)                   | 0.3375    | 0.7625    |
# | Incremental Earnings (Net Income)    | 1.0125    | 2.2875    |
#
# ---

# %% [markdown]
# ### Capital Budgeting: Discount incremental cash flows
#
# AeroDrone Dynamics currently sells its popular "SkyHawk" surveillance drone for $\$1,500$. It is considering lowering the price to $\$1,300$ next year. The cost of goods sold for the SkyHawk is $\$800$ per unit. Current annual sales are 5,000 units.
#
# *   Suppose that if AeroDrone drops the price to $\$1,300$ *immediately* (this year), it can increase this year's sales volume by 30% to 6,500 units. What would be the incremental impact on this year's EBIT from this immediate price drop?
#
#
#     $EBIT = \text{Sales Volume} * (\text{Price - COGS)}$
#
#     $EBIT_{New} = 6,500\, \text{units} * (\$1,300 - \$800) = 6,500 * \$500 = \$3,250,000$
#
#     $EBIT_{Old} = 5,000\, \text{units} * (\$1,500 - \$800) = 5,000 * \$700 = \$3,500,000$
#
#     $\text{Change in EBIT} = EBIT_{New} - EBIT_{Old}$
#
#     $\text{Change in EBIT} = \$3,250,000 - \$3,500,000 = -\$250,000$
#
# ---

# %% [markdown]
# ### Capital Budgeting: Discount incremental cash flows
#
# Suppose that for each drone sold, AeroDrone expects additional sales of $\$200$ per year in battery replacements and software updates for the next three years. AeroDrone has a high gross profit margin of $80\%$ on these related items. What is the incremental impact on EBIT *from these related sales* over the next three years resulting from the immediate price drop (and subsequent sales increase) this year?
#
# Incremental Units Sold = $6,500 - 5,000 = 1,500$ units
#
# Annual EBIT from Related Sales per Drone = $\$200 * 80% = \$160$
#
# Annual Incremental EBIT from Related Sales = Incremental Units * Annual EBIT per Drone = $1,500 * \$160 = \$240,000$
#
# Combined Incremental EBIT Impact:
#
# | Impact Component                 | Year 1       | Year 2       | Year 3       | Total (3 Yrs) |
# | :------------------------------- | -----------: | -----------: | -----------: | ------------: |
# | Drone Sales EBIT Change          | -\$250,000    | \$0           | \$0           | -\$250,000     |
# | Related Sales Incremental EBIT | \$240,000     | \$240,000     | \$240,000     | \$720,000      |
# | Total Incremental EBIT           | -\$10,000     | \$240,000     | \$240,000     | \$470,000      |
#
# ---

# %% [markdown]
# ### Capital Budgeting: Treat inflation consistently
#
# **Discount nominal cash flows using nominal discount rate, real cash flows using the real discount rate.**
#
# Suppose your software company typically forecasts project cash flows in nominal terms and discounts them at a $12\%$ nominal cost of capital. However, for a new app development project, the initial estimates are provided in today's dollars (real terms), and inflation is projected to be $5\%$ per year.
#
# | Real Cash Flows (\$ thousands) | $C_0$ | $C_1$ | $C_2$ | $C_3$ |
# | :---------------------------- | :---: | :---: | :---: | :---: |
# | **Value**                     | -150  | +60   | +80   | +50   |
#
# $\text{Real discount rate} (r_r) = \frac{1 + \text{Nominal discount rate}}{1 + \text{Inflation rate}} - 1 \quad \rightarrow \quad r_r = \frac{1 + 0.12}{1 + 0.05} - 1 = 6.67\% $
#
# **Two Approaches to Calculate NPV:**
#
# 1.  Discount Real Cash Flows at the Real Discount Rate (6.67%)
# 2.  Convert Real Cash Flows to Nominal, then Discount at the Nominal Discount Rate (12.00%)
#
# | t   | Real CF (\$k) | Nominal CF (\$k) [Real * (1+e)^t] | PV Real CF @ 6.67% (\$k) | PV Nominal CF @ 12.00% (\$k) |
# | :-: | -----------: | -----------------------------: | ----------------------: | ------------------------: |
# | 0   | -150.00       | -150.00                         | -150.00                  | -150.00                    |
# | 1   | 60.00         | 63.00                           | 56.25                    | 56.25                      |
# | 2   | 80.00         | 88.20                           | 70.31                    | 70.31                      |
# | 3   | 50.00         | 57.88                           | 41.18                    | 41.18                      |
# |     |               |                                 | NPV = 17.74          | NPV = 17.74            |
#
# ---

# %% [markdown]
# ### Capital Budgeting
#
# #### Separate investment and financing decisions
# *   **Separation Principle:** When securities are fairly priced, the NPV of financing is zero, and so the NPV of an investment is independent of how it is financed.
#
# #### Remember to Deduct Taxes
# *   Taxes are an expense just like wages and raw materials.
# *   Therefore, cash flows should be estimated on an after-tax basis.
# *   Subtract cash outflows for taxes from pretax cash flows and discount the net amount.
#
# ---

# %% [markdown]
# ### Capital Budgeting
#
# *   BioGen Devices is evaluating the development of a new portable diagnostic tool, called "DiagnosTech".
#     *   The device aims to provide rapid, point-of-care results for common infections using a proprietary microfluidic chip.
#     *   BioGen has already completed a $\$500,000$ market analysis study which suggested strong potential demand.
#     *   Sales forecast for DiagnosTech is $50,000$ units per year, and the product is expected to have a five-year market life before being replaced by newer technology.
#     *   The anticipated selling price to distributors is $\$450$ per unit.
#     *   Initial core technology development and device engineering costs are estimated at $\$8$ million.
#     *   Manufacturing will be handled in-house, with an estimated variable production cost of $\$180$ per unit.
#     *   A dedicated team of $30$ specialists (biochemists, software engineers, regulatory experts) will be required for one full year to finalize the device design, testing protocols, and secure regulatory approvals.
#         *   The average fully-loaded cost for each specialist is $\$250,000$ per year.
#     *   An investment of $\$10$ million in new specialized manufacturing and testing equipment is required. This equipment will be purchased and installed immediately (t=0) and will be depreciated using the straight-line method over its *5-year useful life*.
#     *   Annual costs for marketing, sales support, and distribution are projected to be $\$3.5$ million per year once sales begin.
#     *   The product development and setup will take one year (Year 0), with sales commencing at the beginning of Year 1. The company is subject to $35\%$ tax rate.
#
# ---

# %% [markdown]
# ### Capital Budgeting
#
# ### Incremental Earnings Forecast for DiagnosTech
#
# | Incremental Earnings Forecast ($000s)  | Year 0      | 1         | 2         | 3         | 4         | 5         |
# | :------------------------------------- | ----------: | --------: | --------: | --------: | --------: | --------: |
# | 1 Sales                                | —           | 22,500    | 22,500    | 22,500    | 22,500    | 22,500    |
# | 2 Cost of Goods Sold                   | —           | (9,000)   | (9,000)   | (9,000)   | (9,000)   | (9,000)   |
# | 3 **Gross Profit**                     | —           | 13,500    | 13,500    | 13,500    | 13,500    | 13,500    |
# | 4 Selling, General, and Administrative | —           | (3,500)   | (3,500)   | (3,500)   | (3,500)   | (3,500)   |
# | 5 Research and Development             | (15,500)    | —         | —         | —         | —         | —         |
# | 6 Depreciation                         | —           | (2,000)   | (2,000)   | (2,000)   | (2,000)   | (2,000)   |
# | 7 **EBIT**                             | (15,500)    | 8,000     | 8,000     | 8,000     | 8,000     | 8,000     |
# | 8 Income Tax at 35%                    | 5,425       | (2,800)   | (2,800)   | (2,800)   | (2,800)   | (2,800)   |
# | 9 **Unlevered Net Income**             | **(10,075)**| **5,200** | **5,200** | **5,200** | **5,200** | **5,200** |
#
# *Notes on Calculation:*
# *   *R&D (Year 0)* = $\$8,000k$ (Engineering) + (30 specialists * $\$250k/specialist)$ = $\$8,000k + \$7,500k = \$15,500k$.
# *   *Depreciation* = $\$10,000k$ (Equipment Cost) / 5 years = $\$2,000k$ per year for Years 1-5.
# *   *Income Tax (Year 0)* reflects a tax shield/saving from the operating loss (EBIT).
#
# *   **Why do we not include interest expenses when calculating Unlevered Net Income for project evaluation?**
#
# ---

# %% [markdown]
# ### Indirect Effects on Incremental Earnings
# *   **Opportunity Cost**
#     *   Suppose the specialized lab space required for DiagnosTech's final assembly and quality control currently sits vacant. However, BioGen Devices has received an offer to lease this space to a smaller biotech startup for $\$350,000$ per year (after taxes) for the next five years (Years 1-5). Is utilizing this space for DiagnosTech associated with an opportunity cost?
#     *   How does this opportunity cost affect DiagnosTech's incremental earnings?
# *   **Project Externalities**
#     *   Suppose BioGen estimates that approximately $20\%$ of DiagnosTech's projected sales ($50,000$ units/year) will come from existing clients who would have otherwise purchased BioGen's older diagnostic kit, "PathoScreen". PathoScreen has a wholesale price of $\$280$ and a production cost of $\$210$ per unit.
#     *   Product Cannibalization
#         *   Indirect effects of the project that may increase or decrease the profits of other business activities of the firm.
# ---

# %% [markdown]
# ### Incremental Earnings Forecast for DiagnosTech (Including Opportunity Cost & Cannibalization)
#
# | Incremental Earnings Forecast ($000s)     | Year 0      | 1         | 2         | 3         | 4         | 5         |
# | :---------------------------------------- | ----------: | --------: | --------: | --------: | --------: | --------: |
# | 1 Sales                                   | —           | 22,500    | 22,500    | 22,500    | 22,500    | 22,500    |
# | 2 Cost of Goods Sold                      | —           | (9,000)   | (9,000)   | (9,000)   | (9,000)   | (9,000)   |
# | 3 **Gross Profit**                        | —           | 13,500    | 13,500    | 13,500    | 13,500    | 13,500    |
# | 4 Selling, General, and Administrative    | —           | (3,500)   | (3,500)   | (3,500)   | (3,500)   | (3,500)   |
# | 5 Research and Development                | (15,500)    | —         | —         | —         | —         | —         |
# | 6 Depreciation                            | —           | (2,000)   | (2,000)   | (2,000)   | (2,000)   | (2,000)   |
# | 7 Cannibalization (Lost PathoScreen Profit) | —           | (700)     | (700)     | (700)     | (700)     | (700)     |
# | 8 **EBIT**                                | **(15,500)**| **7,300** | **7,300** | **7,300** | **7,300** | **7,300** |
# | 9 Income Tax at 35%                       | 5,425       | (2,555)   | (2,555)   | (2,555)   | (2,555)   | (2,555)   |
# | 10 **Income Before Opportunity Cost**     | (10,075)    | 4,745     | 4,745     | 4,745     | 4,745     | 4,745     |
# | 11 Opportunity Cost (Lab Space, After-Tax)| —           | (350)     | (350)     | (350)     | (350)     | (350)     |
# | 12 **Adjusted Unlevered Net Income**      | **(10,075)**| **4,395** | **4,395** | **4,395** | **4,395** | **4,395** |
#
# **What about the $500,000 market analysis study conducted to assess the potential demand for the new product?**
#
# ---

# %% [markdown]
# ### Capital Budgeting: Sunk Costs and Incremental Earnings
# *   A sunk cost is any unrecoverable cost for which the firm is already liable.
#     *   Fixed overhead expenses
#     *   Past research and development expenditures
#     *   Unavoidable competitive effects
# *   Sunk cost fallacy
#     *   The tendency of people to be influenced by sunk costs and to "throw good money after bad."
# *   Real-World Complexities
# ---

# %% [markdown]
# ### Capital Budgeting: Real-world complexities
#
# * Suppose DiagnosTech sales are now projected as:
#
#     *   Year 1: 50,000 units
#     *   Year 2: 60,000 units
#     *   Year 3: 60,000 units
#     *   Year 4: 40,000 units
#     *   Year 5: 25,000 units
# *   Furthermore, reflecting competitive pressures, the DiagnosTech selling price ($\$450$ initially) is expected to decline by $8\%$ annually. The unit manufacturing cost ($\$180$ initially) is expected to decrease by $5\%$ annually due to process improvements.
# *   Selling, General, and Administrative (SG&A) expenses (\$3.5M initially) are projected to increase by $3\%$ per year due to inflation.
# *   The cannibalization rate remains $20\%$ of DiagnosTech's units sold. However, the price of the cannibalized PathoScreen product ($\$280$ initially) also declines by $6\%$ annually, and its unit cost ($\$210$ initially) declines by $4\%$ annually.
#
# | Factor                            | Year 0 | 1         | 2         | 3         | 4         | 5         |
# | :-------------------------------- | -----: | --------: | --------: | --------: | --------: | --------: |
# | DiagnosTech Units                 |        | 50,000.00    | 60,000.00    | 60,000.00    | 40,000.00    | 25,000.00    |
# | DiagnosTech Price/Unit            |        | \$450.00   | \$414.00   | \$380.88   | \$350.41   | \$322.38   |
# | DiagnosTech Cost/Unit             |        | \$180.00   | \$171.00   | \$162.45   | \$154.33   | \$146.61   |
# | Cannibalized Units (PathoScreen)  |        | 10,000.00    | 12,000.00    | 12,000.00    | 8,000.00     | 5,000.00     |
# | PathoScreen Price/Unit            |        | \$280.00   | \$263.20   | \$247.41   | \$232.56   | \$218.61   |
# | PathoScreen Cost/Unit             |        | \$210.00   | \$201.60   | \$193.54   | \$185.79   | \$178.36   |
# | SG&A Expenses ($000s)             |        | \$3,500.00  | \$3,605.00  | \$3,713.20  | \$3,824.60  | \$3,939.30  |
#
# ---

# %% [markdown]
# ### Capital Budgeting: Real-world complexities
#
# **Revised Incremental Earnings Forecast:**
#
# | Incremental Earnings Forecast ($000s)  | Year 0      | 1         | 2         | 3         | 4         | 5         |
# | :------------------------------------- | ----------: | --------: | --------: | --------: | --------: | --------: |
# | 1 Sales (DiagnosTech)                  | —           | 22,500.0  | 24,840.0  | 22,852.8  | 14,016.4  | 8,059.5   |
# | 2 Cost of Goods Sold (DiagnosTech)     | —           | (9,000.0) | (10,260.0)| (9,747.0) | (6,173.1) | (3,665.3) |
# | 3 **Gross Profit (DiagnosTech)**       | —           | 13,500.0  | 14,580.0  | 13,105.8  | 7,843.3   | 4,394.2   |
# | 4 Less: Lost Profit (Cannibalization)  | —           | (700.0)   | (739.2)   | (646.4)   | (374.1)   | (201.3)   |
# | 5 Selling, General, and Administrative | —           | (3,500.0) | (3,605.0) | (3,713.2) | (3,824.6) | (3,939.3) |
# | 6 Research and Development             | (15,500.0)  | —         | —         | —         | —         | —         |
# | 7 Depreciation                         | —           | (2,000.0) | (2,000.0) | (2,000.0) | (2,000.0) | (2,000.0) |
# | 8 **EBIT**                             | (15,500.0)  | 7,300.0   | 8,235.8   | 6,746.2   | 1,644.5   | (1,746.3) |
# | 9 Income Tax at 35%                    | 5,425.0     | (2,555.0) | (2,882.5) | (2,361.2) | (575.6)   | 611.2     |
# | 10 **Unlevered Net Income**            | **(10,075.0)**| **4,745.0**| **5,353.3**| **4,385.0**| **1,068.9**| **(1,135.1)**|
#
# *   Lost Profit (Cannibalization) = Cannibalized Units * (PathoScreen Price/Unit - PathoScreen Cost/Unit).
# *   EBIT* = Gross Profit (DiagnosTech) - Lost Profit (Cannib.) - SG&A - R&D - Depreciation.
# *   Tax calculation* considers the tax shield effect of losses (negative EBIT).
#
# ---

# %% [markdown]
# ### Determining Free Cash Flow and NPV
# *   Earnings are just an accounting measure of the firm's performance.
#     *   Earnings include non-cash charges, such as depreciation, but do not include the CAPEX.
# *   The incremental effect of a project on the firm's available cash, separate from any financing decisions, is the project's free cash flow.
# *   FCF calculation starts with Unlevered Net Income (UNI) and adjusts for non-cash expenses and cash flows related to investments.
#     *   Add back non-cash expenses (like depreciation).
#     *   Subtract capital expenditures (CAPEX).
#     *   Subtract "increases in net working capital (NWC) or add decreases in NWC.
#
# ---

# %% [markdown]
# ### Determining Free Cash Flow and NPV
# *   Most projects require investments in Net Working Capital (NWC) to support operations.
#     * NWC represents the difference between short-term assets and short-term liabilities needed for the project.
#
#     $ \text{Net Working Capital} = \text{Current Assets} - \text{Current Liabilities} \quad \rightarrow \quad NWC = (\text{Cash}_\text{req} + \text{Inventory} + \text{Receivables}) - (\text{Payables})$
#
# *   **Assumptions:**
#     *   DiagnosTech requires no incremental cash balances beyond normal corporate levels.
#     *   Inventory levels are managed efficiently, requiring no significant incremental investment relative to sales.
#     *   Accounts Receivable are projected to be **10%** of annual sales.
#     *   Accounts Payable are projected to be **20%** of the annual Cost of Goods Sold (COGS).
#
# **Net Working Capital Forecast for DiagnosTech ($000s):**
#
# | Net Working Capital Components       | Year 0 | Year 1     | Year 2     | Year 3     | Year 4     | Year 5 |
# | :----------------------------------- | :-----: | ---------: | ---------: | ---------: | ---------: | :-----: |
# | 1 Cash Requirements                  | —      | —          | —          | —          | —          | —      |
# | 2 Inventory                          | —      | —          | —          | —          | —          | —      |
# | 3 Receivables (10% of Sales)        | —      | 2,250      | 2,250      | 2,250      | 2,250      | —      |
# | 4 Payables (20% of COGS)            | —      | (1,800)    | (1,800)    | (1,800)    | (1,800)    | —      |
# | 5 **Net Working Capital (NWC)**      | **—**  | **450**    | **450**    | **450**    | **450**    | **—**  |
#
# ---

# %% [markdown]
# ### Determining Free Cash Flow and NPV
# |                                | Year 0      | Year 1     | Year 2     | Year 3     | Year 4     | Year 5     |
# | :----------------------------- | ----------: | ---------: | ---------: | ---------: | ---------: | ---------: |
# | **Incremental Earnings (\$000s)**|             |            |            |            |            |            |
# | 1 Sales                       | —           | 22,500     | 22,500     | 22,500     | 22,500     | 22,500     |
# | 2 Cost of Goods Sold          | —           | (9,000)    | (9,000)    | (9,000)    | (9,000)    | (9,000)    |
# | 3 **Gross Profit**            | —           | 13,500     | 13,500     | 13,500     | 13,500     | 13,500     |
# | 4 SG&A                        | —           | (3,500)    | (3,500)    | (3,500)    | (3,500)    | (3,500)    |
# | 5 R&D                         | (15,500)    | —          | —          | —          | —          | —          |
# | 6 Depreciation                | —           | (2,000)    | (2,000)    | (2,000)    | (2,000)    | (2,000)    |
# | 7 **EBIT**                    | (15,500)    | 8,000      | 8,000      | 8,000      | 8,000      | 8,000      |
# | 8 Income Tax @ 35%            | 5,425       | (2,800)    | (2,800)    | (2,800)    | (2,800)    | (2,800)    |
# | 9 **Unlevered Net Income**    | **(10,075)**| **5,200**  | **5,200**  | **5,200**  | **5,200**  | **5,200**  |
# | **Free Cash Flow ($000s)**     |             |            |            |            |            |            |
# | 10 Plus: Depreciation          | —           | 2,000      | 2,000      | 2,000      | 2,000      | 2,000      |
# | 11 Less: Capital Expenditures  | (10,000)    | —          | —          | —          | —          | —          |
# | 12 Less: Increases in NWC   | —           | (450)      | —          | —          | —          | 450        |
# | 13 **Free Cash Flow**          | **(20,075)**| **6,750**  | **7,200**  | **7,200**  | **7,200**  | **7,650**  |
#
# ---

# %% [markdown]
# ### Determining Free Cash Flow and NPV
#
# * The final step is to determine the project's value by calculating the Net Present Value (NPV).
# * This involves discounting the project's Free Cash Flows (FCFs) back to the present using the appropriate project cost of capital.
# * Let's assume the cost of capital for the DiagnosTech project is $12\%$.
#
# **DiagnosTech NPV Calculation ($000s):**
#
# |                                | Year 0      | Year 1    | Year 2    | Year 3    | Year 4    | Year 5    |
# | :----------------------------- | ----------: | --------: | --------: | --------: | --------: | --------: |
# | 1 Free Cash Flow               | (20,075.0)    | 6,750.0     | 7,200.0     | 7,200.0     | 7,200.0     | 7,650.0     |
# | 2 Project Cost of Capital      | 12%         |           |           |           |           |           |
# | 3 Discount Factor (1/(1.12)ᵗ)  | 1.0000      | 0.8929    | 0.7972    | 0.7118    | 0.6355    | 0.5674    |
# | 4 PV of Free Cash Flow         | (20,075.0)  | 6,026.8   | 5,739.8   | 5,124.8   | 4,575.7   | 4,340.9   |
# | 5 **Net Present Value (NPV)**  | **5,733.0** |           |           |           |           |           |
#
# ---

# %% [markdown]
# ### Calculating Free Cash Flow Directly
#
# 1.  **Using Unlevered Net Income:**
#     $$ \text{Free Cash Flow} = \overbrace{(\text{Revenues} – \text{Costs} - \text{Depreciation}) \times (1 – \tau_c)}^{\text{Unlevered Net Income}} + \text{Depreciation} – \text{CapEx} – \Delta \text{NWC} $$
#     *   Where "Costs" represent operating costs excluding depreciation (e.g., COGS + SG&A).
#     *   $\tau_c$ is the corporate tax rate.
#
# 2.  **Using operating cash flow before depreciation tax shield:**
#     $$ \text{Free Cash Flow} = (\text{Revenues} – \text{Costs}) \times (1 – \tau_c) – \text{CapEx} – \Delta \text{NWC} + (\tau_c \times \text{Depreciation}) $$
#     *   This formula calculates the after-tax cash flow from operations as if there were no depreciation, then separately adds the tax savings provided by the depreciation deduction (the Depreciation Tax Shield, $\tau_c \times \text{Depreciation}$).
#
# 3.  **Starting from EBIT:**
#     $$ \text{Free Cash Flow} = \overbrace{\text{EBIT} \times (1 – \tau_c)}^{\text{Unlevered Net Income}} + \text{Depreciation} – \text{CapEx} – \Delta \text{NWC} $$
#
# ### Present Value Calculation
#
# $$ PV(FCF_t) = \frac{FCF_t}{(1+r)^t} = FCF_t \times \overbrace{\frac{1}{(1+r)^t}}^{\text{Discount Factor for Year t}} $$
#
# ---

# %% [markdown]
# ### Calculating Free Cash Flow Directly
#
# **Data Recap:**
# *   Tax Rate ($\tau_c$): 35% (0.35)
# *   **Year 1:** Revenues = $\$22,500k$; Costs (COGS+SG&A) = $\$12,500k$; Depreciation = $\$2,000k$; EBIT = $\$8,000k$; CapEx = $\$0$; ΔNWC = $+\$450k$.
#
# **Calculating FCF for Year 1 ($000s):**
#
# 1.  **Using Unlevered Net Income:**
#
#     $ \text{FCF} = \underbrace{(\text{Rev} – \text{Costs} - \text{Depreciation}) \times (1 – \tau_c)}_{\text{UNI}} + \text{Depreciation} – \text{CapEx} – \Delta \text{NWC} $
#
#     $ \text{FCF}_1 = \underbrace{(22,500 – 12,500 - 2,000) \times (1 – 0.35)}_{5,200} + 2,000 – 0 – 450 \quad \rightarrow \quad \text{FCF}_1 = (8,000 \times 0.65) + 2,000 - 450 = \mathbf{6,750} $
#
# 2.  **Using Depreciation Tax Shield:**
#
#     $ \text{FCF} = (\text{Rev} – \text{Costs}) \times (1 – \tau_c) – \text{CapEx} – \Delta \text{NWC} + (\tau_c \times \text{Depreciation}) $
#
#     $ \text{FCF}_1 = (22,500 – 12,500) \times (1 – 0.35) – 0 – 450 + (0.35 \times 2,000) \quad \rightarrow \quad \text{FCF}_1 = (10,000 \times 0.65) - 450 + 700 = \mathbf{6,750} $
#
# 3.  **Starting from EBIT:**
#
#     $ \text{FCF} = \underbrace{\text{EBIT} \times (1 – \tau_c)}_{\text{UNI}} + \text{Depreciation} – \text{CapEx} – \Delta \text{NWC} $
#
#     $ \text{FCF}_1 = \underbrace{8,000 \times (1 – 0.35)}_{5,200} + 2,000 – 0 – 450 \quad \rightarrow \quad \text{FCF}_1 = 5,200 + 2,000 - 450 = \mathbf{6,750} $
#
# ---

# %% [markdown]
# ### Calculating Free Cash Flow (FCF)
#
# *   Suppose you manage a growing consulting firm and considering upgrading the office's technology infrastructure (servers, network gear).
#     * This upgrade is expected to increase annual billable revenues by $\$70,000$ due to improved efficiency and capabilities, but also increase annual operating expenses (support, licenses, power) by $\$40,000$.
#     * The depreciation expense associated with the new technology for the first year is estimated at $\$15,000$.
#     * Your firm's marginal tax rate is $30\%$.
#     * Minor capital expenditures of $\$5,000$ will be required next year for peripheral component replacements, and no change in net working capital is anticipated for this specific project.
#     * Calculate the project's Free Cash Flow (FCF) for the next year.
#
#     $ \text{Free Cash Flow} = (\text{Revenues} – \text{Costs}) \times (1 – \tau_c) – \text{CapEx} – \Delta NWC + \tau_c \times \text{Depreciation} $
#
#     $ \text{FCF} = (\$70,000 – \$40,000) \times (1 – 0.30) – \$5,000 - \$0 + 0.30 \times \$15,000 $
#
#     $ \text{FCF} = (\$30,000) \times (0.70) – \$5,000 + \$4,500 $
#
#     $ \text{FCF} = \$21,000 – \$5,000 + \$4,500 $
#
#     $ \text{FCF} = \$20,500 $
#
# ---

# %% [markdown]
# ### Calculating Operating Cash Flow (OCF)
#
# *   A local bakery, estimates that its new line of gluten-free pastries will generate annual sales of $\$500,000$. The associated operating costs (ingredients, labor, packaging) are expected to be $\$250,000$ per year, and the annual depreciation expense on the new specialized ovens and mixers is $\$50,000$. If the bakery's tax rate is $25\%$, what is the expected annual Operating Cash Flow (OCF) from this new line?
#
#     **Method 1: Tax Shield Approach**
#
#     $ OCF = (\text{Revenues} – \text{Costs}) \times (1 - \tau_c) + (\tau_c \times \text{Depreciation}) $
#
#     $ OCF = (\$500,000 – \$250,000) \times (1 – 0.25) + (0.25 \times \$50,000) $
#
#     $ OCF = (\$250,000) \times (0.75) + \$12,500 \qquad \rightarrow \qquad OCF = \$200,000 $
#
#     **Method 2: Unlevered Net Income + Depreciation**
#
#     $ \text{Free Cash Flow} = \overbrace{(\text{Revenues} – \text{Costs} - \text{Depreciation}) \times (1 − \tau_c)}^{\text{Unlevered Net Income}} + \text{Depreciation} - \text{CapEx} - \Delta NWC $
#
#     $ \text{Unlevered NI} = (\text{Revenues} – \text{Costs} - \text{Depreciation}) \times (1 − \tau_c) $
#
#     $ \text{Unlevered NI} = (\$500,000 – \$250,000 – \$50,000) \times (1 – 0.25) \qquad \rightarrow \qquad  \text{Unlevered NI} = (\$200,000) \times (0.75) = \$150,000 $
#
#     $ OCF = \text{Unlevered Net Income} + \text{Depreciation} - \text{CapEx} - \Delta NWC $
#
#     $ OCF = \$150,000 + \$50,000 = \$200,000 $
#
#     ---

# %% [markdown]
# ### Further Adjustments to Free Cash Flow
# *   Other non-cash items
#     *   Amortization of intangible assets
# *   Timing of cash flows
#     *   Quarterly or monthly estimations
# *   Accelerated depreciation
#     *   How does it affect the PV of cash flows?
# *   Liquidation or salvage value
#     *   Gain on Sale = Sale Price - Book Value
#     *   Book Value = Purchase Price - Accumulated Depreciation
#     *   After-Tax Cash Flow from Asset Sale = Sale Price - ($\tau_c$ * Gain on Sale)
# *   Terminal or continuation value
#     *   Indefinite life or project life beyond forecast horizon
# *   Tax carryforwards and carrybacks
#
# ---

# %% [markdown]
# ### Further Adjustments to Free Cash Flow: Example
#
# *   Alpine Gear Outfitters is considering introducing a new line of high-tech hiking boots.
#     * This three-year project requires an initial fixed asset investment (new manufacturing equipment) of $\$2.1$ million. The equipment will be depreciated straight-line to zero over its three-year tax life, after which it will be considered worthless for salvage purposes.
#     * The project is estimated to generate $\$1.5$ million in annual sales, with costs of $\$600,000$ per year. The applicable tax rate is $30$ percent, and the company's required return for this type of project is $11$ percent.
#     * What is the project's Net Present Value (NPV)?
#
#     **Calculate the annual Operating Cash Flow (OCF):**
#
#     $ \text{Annual Depreciation} = \frac{\text{Initial Investment}}{\text{Project Life}} = \frac{\$2,100,000}{3} = \$700,000 $
#
#     $ OCF = (\text{Revenues} - \text{Costs}) \times (1 - \tau_c) + \tau_c \times \text{Depreciation} $
#
#     $ OCF = (\$1,500,000 – \$600,000) \times (1 – 0.30) + 0.30 \times \$700,000 \quad \rightarrow \quad OCF = \$840,000 $
#
#     **Calculate the project NPV:**
#
#     $ NPV = \sum_{t=0}^{n} \frac{FCF_t}{(1+r)^t} = FCF_0 + \frac{FCF_1}{(1 + r)^1} + \dots + \frac{FCF_n}{(1 + r)^n} $
#
#     $ NPV = \text{-Initial Investment} + \sum_{t=1}^{3} \frac{OCF}{(1+r)^t} $
#
#     $ NPV = -\$2,100,000 + \frac{\$840,000}{(1 + 0.11)^1} + \frac{\$840,000}{(1 + 0.11)^2} + \frac{\$840,000}{(1 + 0.11)^3} \quad \text{or} \quad NPV = -\$2,100,000 + \$840,000 \times \left[ \frac{1 - \frac{1}{(1 + 0.11)^3}}{0.11} \right] = -\$47,283.60 $
#
#     ---

# %% [markdown]
# ### Further Adjustments to Free Cash Flow: Example
#
# *   Now, suppose the boot project also requires an initial investment in net working capital (NWC) of $\$350,000$, which will be fully recovered at the end of the project. Furthermore, assume the manufacturing equipment will have a market (salvage) value of $\$250,000$ at the end of the three years. What are the project's Free Cash Flows (FCFs) for each year? Recalculate the project NPV with these additional factors.
#
#     $ \text{Gain on Sale} = \text{Market Value} - \text{Book Value} = \$250,000 - \$0 = \$250,000 $
#
#     $ \text{Tax on Gain} = \tau_c \times \text{Gain on Sale} = 0.30 \times \$250,000 = \$75,000 $
#
#     $ \text{After-tax Salvage Value} = \text{Market Value} - \text{Tax on Gain} = \$250,000 - \$75,000 = \$175,000 $
#
#     | Incremental Earnings & FCF | 0               | 1             | 2             | 3               |
#     | :------------------------- | --------------: | ------------: | ------------: | --------------: |
#     | Revenues                   |                 | 1,500,000.00  | 1,500,000.00  | 1,500,000.00    |
#     | Costs                      |                 | 600,000.00    | 600,000.00    | 600,000.00      |
#     | **Gross Profit**           |                 | **900,000.00**| **900,000.00**| **900,000.00**  |
#     | Depreciation (SL)          |                 | 700,000.00    | 700,000.00    | 700,000.00      |
#     | **EBIT**                   |                 | **200,000.00**| **200,000.00**| **200,000.00**  |
#     | Tax (30%)                  |                 | 60,000.00     | 60,000.00     | 60,000.00       |
#     | **Unlevered Net Income**   |                 | **140,000.00**| **140,000.00**| **140,000.00**  |
#     | **Free Cash Flow**         |                 |               |               |                 |
#     | Plus: Depreciation         |                 | 700,000.00    | 700,000.00    | 700,000.00      |
#     | Less: CAPEX                | 2,100,000.00    |               |               |                 |
#     | Less/Plus: $\Delta NWC$     | 350,000.00      |               |               | -350,000.00     |
#     | Plus: Salvage Value (AT)   |                 |               |               | 175,000.00      |
#     | **Free Cash Flow**         | **-2,450,000.00**| **840,000.00**| **840,000.00**| **1,365,000.00**|
#     | PV (@ r=11%)               | -2,450,000.00   | 756,756.76    | 681,762.84    | 998,069.97      |
#     | **NPV (@ r=11%)**          | **-13,410.43**  |               |               |                 |
#
# ---

# %% [markdown]
# ### Further Adjustments to Free Cash Flow: Example
# *   Finally, suppose Alpine Gear Outfitters uses a specific accelerated depreciation method where *50% of the beginning-of-year book value is depreciated each year*. All other facts remain the same (initial investment $\$2.1M$, NWC $\$350k$, salvage $\$250k$, tax 30%, return 11%). What are the project's FCFs under this depreciation schedule? What is the new NPV?
#
#     **Calculate the Accelerated Depreciation:**
#     $ \text{Depreciation Year 1} = 0.50 \times \$2,100,000 = \$1,050,000 \quad (\text{BV}_\text{End Y1} = \$1,050,000) $
#
#     $ \text{Depreciation Year 2} = 0.50 \times \$1,050,000 = \$525,000 \quad (\text{BV}_\text{End Y2} = \$525,000) $
#
#     $ \text{Depreciation Year 3} = 0.50 \times \$525,000 = \$262,500 \quad (\text{BV}_\text{End Y3} = \$262,500) $
#
#     **Calculate Book Value and Tax Effect on Salvage:**
#     $ \text{Book Value}_{\text{End Y3}} = \$262,500 $
#
#     $ \text{Gain/(Loss) on Sale} = \text{Market Value} – \text{Book Value}_{\text{End Y3}} \quad \rightarrow \quad \text{Gain/(Loss) on Sale} = -\$12,500 \quad (\text{Capital Loss}) $
#
#     $ \text{Tax Effect on Sale} = \tau_c \times \text{Gain/(Loss) on Sale} = 0.30 \times (-\$12,500) = -\$3,750 \quad (\text{Tax Shield}) $
#
#     $ \text{After–Tax Cash Flow from Asset Sale (ATSV)} = \text{Market Value} - \text{Tax Effect on Sale}$
#
#     $\text{ATSV} = \$250,000 - (-\$3,750) = \$250,000 + \$3,750 = \$253,750 $
#
#        | Incremental Earnings & FCF | 0               | 1             | 2             | 3               |
#     | :------------------------- | --------------: | ------------: | ------------: | --------------: |
#     | Revenues                   |                 | 1,500,000.00  | 1,500,000.00  | 1,500,000.00    |
#     | Costs                      |                 | 600,000.00    | 600,000.00    | 600,000.00      |
#     | **Gross Profit**           |                 | **900,000.00**| **900,000.00**| **900,000.00**  |
#     | Depreciation (Accel 50%BV) |                 | 1,050,000.00  | 525,000.00    | 262,500.00      |
#     | **EBIT**                   |                 | **-150,000.00**| **375,000.00**| **637,500.00**  |
#     | Tax (30%)                  |                 | -45,000.00    | 112,500.00    | 191,250.00      |
#     | **Unlevered Net Income**   |                 | **-105,000.00**| **262,500.00**| **446,250.00**  |
#     | **Free Cash Flow**         |                 |               |               |                 |
#     | Plus: Depreciation         |                 | 1,050,000.00  | 525,000.00    | 262,500.00      |
#     | Less: CAPEX                | 2,100,000.00    |               |               |                 |
#     | Less/Plus: $\Delta$NWC     | 350,000.00      |               |               | -350,000.00     |
#     | Plus: Salvage Value (AT)   |                 |               |               | 253,750.00      |
#     | **Free Cash Flow**         | **-2,450,000.00**| **945,000.00**| **787,500.00**| **1,312,500.00**|
#     | PV (@ r=11%)               | -2,450,000.00   | 851,351.35    | 638,961.04    | 959,783.70      |
#     | **NPV (@ r=11%)**          | **96.09**       |               |               |                 |
#
# ---

# %% [markdown]
# ### Analyzing the Project
#
# **Break-even analysis**
# *   The level of input for which the investment has an NPV of zero.
# *   Does IRR point to a break-even level?
# *   EBIT break-even
#
# **Sensitivity analysis**
# *   Breaks the NPV calculation into its component assumptions and shows how the NPV varies as the underlying assumptions change.
# *   Allows us to explore the effects of variations in our NPV estimates for the project.
#
# **Scenario analysis**
# *   Considers the effect on the NPV of changing multiple project parameters
#
# ---

# %% [markdown]
# ### Break-even Analysis
# *   BioGen Devices is evaluating the development of a new portable diagnostic tool, called "DiagnosTech".
#     *   The device aims to provide rapid, point-of-care results for common infections using a proprietary microfluidic chip. BioGen has already completed a \$500,000 market analysis study which suggested strong potential demand.
#     *   Sales forecast for DiagnosTech is 50,000 units per year, and the product is expected to have a five-year market life before being replaced by newer technology. The anticipated selling price to distributors is \$450 per unit.
#     *   Initial core technology development and device engineering costs are estimated at \$8 million.
#     *   Manufacturing will be handled in-house, with an estimated variable production cost of \$180 per unit.
#     *   A dedicated team of 30 specialists (biochemists, software engineers, regulatory experts) will be required for one full year to finalize the device design, testing protocols, and secure regulatory approvals. The average fully-loaded cost for each specialist is \$250,000 per year.
#     *   An investment of \$10 million in new specialized manufacturing and testing equipment is required. This equipment will be purchased and installed immediately (t=0) and will be depreciated using the straight-line method over its 5-year useful life.
#     *   Annual costs for marketing, sales support, and distribution are projected to be \$3.5 million per year once sales begin.
#     *   The product development and setup will take one year (Year 0), with sales commencing at the beginning of Year 1.
#     *   DiagnosTech requires no incremental cash balances beyond normal corporate levels. Inventory levels are managed efficiently, requiring no significant incremental investment relative to sales. Accounts receivable are projected to be 10% of annual sales. Accounts payable are projected to be 20% of the annual Cost of Goods Sold (COGS).
#     * The cost of capital for the project is estimated to be 12%.
#
#     **Base Case NPV and IRR Calculation**
#
# |                                | **Year 0**     | **Year 1**  | **Year 2**  | **Year 3**  | **Year 4**  | **Year 5**  |
# |:------------------------------- | -------------: | ----------: | ----------: | ----------: | ----------: | ----------: |
# | **1 Free Cash Flow**           | (20,075.00)    | 6,750.00    | 7,200.00    | 7,200.00    | 7,200.00    | 7,650.00    |
# | **2 NPV at 12%** (in \$000)    | 5,734.00       |             |             |             |             |             |
# | **3 IRR**                       | 22.78%         |             |             |             |             |             |
#
#
# ---

# %% [markdown]
# ### Break-even analysis – DiagnosTech
#
# - **Initial investment (Year 0)**:  $\quad FCF_0 = -(R\&D \times (1 - Tax) + CapEx) $
# - **Year 1 FCF**: $\qquad \qquad \qquad \quad FCF_1(Q, P, VC) = OCF_1(Q, P, VC) - NWC_1(Q, P, VC)$
# - **Years 2–4 FCF**:  $\qquad \qquad \qquad FCF_{2-4}(Q, P, VC) = OCF(Q, P, VC)$
# - **Year 5 FCF**: $\qquad \qquad \qquad \quad FCF_5(Q, P, VC) = OCF_5(Q, P, VC) + NWC_1(Q, P, VC)$
#
# - **Operating Cash Flow (OCF)**: $\quad OCF(Q, P, VC) = \left[ (Q \cdot P - Q \cdot VC - SG\&A - Depreciation) \cdot (1 - Tax) \right] + Depreciation$
#
# - **Net Working Capital (NWC)**: $\quad NWC_1(Q, P, VC) = 0.10 \cdot (P \cdot Q) - 0.20 \cdot (VC \cdot Q)$
#
# **Objective Function for Break-Even Calculation:**
#
# The break-even point occurs when the project's Net Present Value (NPV) is zero. Thus, we have the general form:
#
# $NPV(Q,P,VC,r) = FCF_0 + \frac{FCF_1(Q,P,VC)}{(1+r)^1} + \frac{FCF_2(Q,P,VC)}{(1+r)^2} + \frac{FCF_3(Q,P,VC)}{(1+r)^3} + \frac{FCF_4(Q,P,VC)}{(1+r)^4} + \frac{FCF_5(Q,P,VC)}{(1+r)^5}=0$
#
# **Parameter**           | **Break-Even Level**
# -------------------------|-------------------------------
# Units sold               | 40,938.09 units per year
# Wholesale price          | \$401.07 per unit
# Cost of goods            | \$228.93 per unit
# Cost of capital          | 22.78% (IRR)
#
# ---

# %% [markdown]
# ### Capital Budgeting - Sensitivity analysis
#
# | Parameter                 | Initial<br>Assumption | Worst Case<br>Scenario | Worst Case<br>NPV (\$M) | Base Case<br>NPV (\$M) | Best Case<br>Scenario | Best Case<br>NPV (\$M) |
# |:--------------------------|---------------------:|----------------------:|----------------------:|---------------------:|---------------------:|---------------------:|
# | Units sold (thousands)    | 50                   | 30                     | -6.92                  | 5.73                  | 75                    | 21.55                 |
# | Sale price (\$/unit)        | 450                  | 250                    | -17.70                 | 5.73                  | 575                   | 20.38                 |
# | Cost of goods (\$/unit)     | 180                  | 300                    | -8.33                  | 5.73                  | 120                   | 12.76                 |
# | Cost of capital (%)        | 12                   | 18                     | 2.26                   | 5.73                  | 10                    | 7.09                  |
#
#
# <center>
# <img src="../figures/budgeting_sensitivity.png" width="720"/>
# </center>
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
price = 450.0                  # Wholesale price per unit ($)
cogs = 180.0                   # Cost of goods per unit ($)
fixed_SGA = 3500               # Annual SG&A ($000)
annual_depr = 2000             # Annual depreciation ($000)
tax_rate = 0.35                # Tax rate
capex_initial = 10000          # Initial CapEx at year 0 ($000)
RD_initial = 15500             # Initial R&D expense at year 0 ($000)
NWC_year1 = 450                # NWC outflow in Year 1 ($000)
NWC_year5 = -450               # NWC inflow in Year 5 ($000)
discount_rate = 0.12           # Discount rate (12%)

# Years array
years = np.arange(6)

# FCF calculation with immediate tax deduction on R&D
def calculate_fcfs(units):
    sales = units * price / 1000
    cost_of_goods = units * cogs / 1000

    # EBIT and Taxes from year 1 onwards
    ebit = sales - cost_of_goods - fixed_SGA - annual_depr
    tax = ebit * tax_rate
    net_income = ebit - tax

    fcfs = np.zeros(6)

    # Year 0 includes tax shield from immediate R&D expense
    fcfs[0] = -(RD_initial * (1 - tax_rate) + capex_initial)

    # Years 1 to 5 FCFs
    fcfs[1] = net_income + annual_depr - NWC_year1
    fcfs[2:5] = net_income + annual_depr
    fcfs[5] = net_income + annual_depr - NWC_year5

    return fcfs

# NPV calculation
def npv(fcfs, rate=discount_rate):
    return sum(fcfs[t] / (1 + rate)**t for t in range(len(fcfs)))

# Plot setup
units_range = np.linspace(10000, 70000, 200)
npv_values = [npv(calculate_fcfs(u)) for u in units_range]

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(units_range, npv_values, label='NPV vs Units Sold')
plt.axhline(0, color='black', linewidth=0.7, linestyle='--')
plt.xlabel('Units Sold per Year')
plt.ylabel('NPV ($000)')
plt.title('NPV vs. Units Sold')
plt.grid(True)

# Break-even annotation
break_even_units = np.interp(0, npv_values, units_range)
plt.scatter(break_even_units, 0, color='red', label=f'Break-even: {break_even_units:.0f} Units')
plt.annotate(f'{break_even_units:.0f} Units', 
             (break_even_units, 0), 
             xytext=(break_even_units + 2000, max(npv_values)/10),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
units_sold = 50000             # Annual units sold
cogs = 180.0                   # Cost of goods per unit ($)
fixed_SGA = 3500               # Annual SG&A ($000)
annual_depr = 2000             # Annual depreciation ($000)
tax_rate = 0.35                # Corporate tax rate
capex_initial = 10000          # Initial CapEx at year 0 ($000)
RD_initial = 15500             # Initial R&D expense at year 0 ($000)
NWC_year1 = 450                # NWC outflow in Year 1 ($000)
NWC_year5 = -450               # NWC inflow in Year 5 ($000)
discount_rate = 0.12           # Discount rate (12%)

# FCF calculation with immediate tax deduction for R&D
def calculate_fcfs(price):
    sales = units_sold * price / 1000
    cost_of_goods = units_sold * cogs / 1000

    ebit = sales - cost_of_goods - fixed_SGA - annual_depr
    tax = ebit * tax_rate
    net_income = ebit - tax

    fcfs = np.zeros(6)

    # Year 0 FCF with immediate R&D tax shield
    fcfs[0] = -(RD_initial * (1 - tax_rate) + capex_initial)

    # Years 1 to 5
    fcfs[1] = net_income + annual_depr - NWC_year1
    fcfs[2:5] = net_income + annual_depr
    fcfs[5] = net_income + annual_depr - NWC_year5

    return fcfs

# NPV function
def npv(fcfs, rate=discount_rate):
    return sum(fcfs[t] / (1 + rate)**t for t in range(len(fcfs)))

# Generate price range and calculate NPVs
price_range = np.linspace(200, 600, 200)
npv_values = [npv(calculate_fcfs(p)) for p in price_range]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(price_range, npv_values, label='NPV vs Unit Sale Price')
plt.axhline(0, color='black', linewidth=0.7, linestyle='--')
plt.xlabel('Unit Sale Price ($)')
plt.ylabel('NPV ($000)')
plt.title('NPV vs. Wholesale Price per Unit')
plt.grid(True)

# Identify and annotate break-even price
break_even_price = np.interp(0, npv_values, price_range)
plt.scatter(break_even_price, 0, color='red', label=f'Break-even: ${break_even_price:.2f}')
plt.annotate(f'${break_even_price:.2f}', 
             (break_even_price, 0), 
             xytext=(break_even_price + 20, max(npv_values)/10),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
units_sold = 50000              # Annual units sold
price = 450.0                   # Wholesale price per unit ($)
fixed_SGA = 3500                # Annual SG&A ($000)
annual_depr = 2000              # Annual depreciation ($000)
tax_rate = 0.35                 # Corporate tax rate
capex_initial = 10000           # Initial CapEx at year 0 ($000)
RD_initial = 15500              # Initial R&D expense at year 0 ($000)
NWC_year1 = 450                 # NWC outflow in Year 1 ($000)
NWC_year5 = -450                # NWC inflow in Year 5 ($000)
discount_rate = 0.12            # Discount rate (12%)

# FCF calculation with immediate tax deduction for R&D
def calculate_fcfs(cogs):
    sales = units_sold * price / 1000
    cost_of_goods = units_sold * cogs / 1000

    ebit = sales - cost_of_goods - fixed_SGA - annual_depr
    tax = ebit * tax_rate
    net_income = ebit - tax

    fcfs = np.zeros(6)

    # Year 0 FCF with immediate R&D tax shield
    fcfs[0] = -(RD_initial * (1 - tax_rate) + capex_initial)

    # Years 1 to 5
    fcfs[1] = net_income + annual_depr - NWC_year1
    fcfs[2:5] = net_income + annual_depr
    fcfs[5] = net_income + annual_depr - NWC_year5

    return fcfs

# NPV function
def npv(fcfs, rate=discount_rate):
    return sum(fcfs[t] / (1 + rate)**t for t in range(len(fcfs)))

# Generate COGS range and calculate NPVs
cogs_range = np.linspace(100, 400, 200)
npv_values = [npv(calculate_fcfs(c)) for c in cogs_range]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(cogs_range, npv_values, label='NPV vs Unit Variable Cost (COGS)')
plt.axhline(0, color='black', linewidth=0.7, linestyle='--')
plt.xlabel('Unit Variable Cost ($)')
plt.ylabel('NPV ($000)')
plt.title('NPV vs. Unit Variable Cost (COGS)')
plt.grid(True)

# Identify and annotate break-even COGS
break_even_cogs = np.interp(0, npv_values[::-1], cogs_range[::-1])
plt.scatter(break_even_cogs, 0, color='red', label=f'Break-even COGS: ${break_even_cogs:.2f}')
plt.annotate(f'${break_even_cogs:.2f}',
             (break_even_cogs, 0),
             xytext=(break_even_cogs + 10, max(npv_values)/10),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
units_sold = 50000              # Annual units sold
price = 450.0                   # Wholesale price per unit ($)
cogs = 180.0                    # Cost of goods per unit ($)
fixed_SGA = 3500                # Annual SG&A ($000)
annual_depr = 2000              # Annual depreciation ($000)
tax_rate = 0.35                 # Corporate tax rate
capex_initial = 10000           # Initial CapEx at year 0 ($000)
RD_initial = 15500              # Initial R&D expense at year 0 ($000)
NWC_year1 = 450                 # NWC outflow in Year 1 ($000)
NWC_year5 = -450                # NWC inflow in Year 5 ($000)

# FCF calculation with immediate R&D tax shield
def calculate_fcfs():
    sales = units_sold * price / 1000
    cost_of_goods = units_sold * cogs / 1000

    ebit = sales - cost_of_goods - fixed_SGA - annual_depr
    tax = ebit * tax_rate
    net_income = ebit - tax

    fcfs = np.zeros(6)

    # Year 0 FCF with immediate R&D tax shield
    fcfs[0] = -(RD_initial * (1 - tax_rate) + capex_initial)

    # Years 1 to 5
    fcfs[1] = net_income + annual_depr - NWC_year1
    fcfs[2:5] = net_income + annual_depr
    fcfs[5] = net_income + annual_depr - NWC_year5

    return fcfs

# NPV calculation
def npv(fcfs, rate):
    return sum(fcfs[t] / (1 + rate)**t for t in range(len(fcfs)))

# Generate discount rate (cost of capital) range and calculate NPVs
rate_range = np.linspace(0.01, 0.50, 200)  # From 1% to 50%
fcfs = calculate_fcfs()
npv_values = [npv(fcfs, r) for r in rate_range]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(rate_range * 100, npv_values, label='NPV vs Cost of Capital')
plt.axhline(0, color='black', linewidth=0.7, linestyle='--')
plt.xlabel('Cost of Capital (%)')
plt.ylabel('NPV ($000)')
plt.title('NPV vs. Cost of Capital')
plt.grid(True)

# Identify and annotate IRR (break-even cost of capital)
irr = np.interp(0, npv_values[::-1], rate_range[::-1]) * 100
plt.scatter(irr, 0, color='red', label=f'IRR (Break-even): {irr:.2f}%')
plt.annotate(f'{irr:.2f}%', 
             (irr, 0), 
             xytext=(irr + 2, max(npv_values)/10),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
# Re-import required libraries and re-run sensitivity analysis

from posixpath import ismount
import numpy as np
import matplotlib.pyplot as plt

# Redefine constants (initial assumptions)
units_initial = 50000
price_initial = 450
cogs_initial = 180
discount_initial = 0.12

fixed_SGA = 3500
annual_depr = 2000
tax_rate = 0.35
capex_initial = 10000
RD_initial = 15500
NWC_year1 = 450
NWC_year5 = -450

# Define scenarios (Worst, Base, Best)
scenarios = {
    'Units Sold': [30000, units_initial, 75000],
    'Sale Price': [250, price_initial, 575],
    'Cost of Goods': [300, cogs_initial, 120],
    'Cost of Capital': [0.18, discount_initial, 0.10]
}

# FCF calculation with immediate R&D tax shield
def calculate_fcfs(units, price, cogs):
    sales = units * price / 1000
    cost_of_goods = units * cogs / 1000
    ebit = sales - cost_of_goods - fixed_SGA - annual_depr
    tax = ebit * tax_rate
    net_income = ebit - tax
    fcfs = np.zeros(6)
    fcfs[0] = -(RD_initial * (1 - tax_rate) + capex_initial)
    fcfs[1] = net_income + annual_depr - NWC_year1
    fcfs[2:5] = net_income + annual_depr
    fcfs[5] = net_income + annual_depr - NWC_year5
    return fcfs

# NPV calculation
def npv(rate, fcfs):
    return sum(fcfs[t] / (1 + rate)**t for t in range(len(fcfs)))

# Compute base NPV
base_npv = npv(discount_initial, calculate_fcfs(units_initial, price_initial, cogs_initial))

# Compute NPVs for each scenario
npv_ranges = {}
for param, (worst, base, best) in scenarios.items():
    if param == 'Units Sold':
        low = npv(discount_initial, calculate_fcfs(worst, price_initial, cogs_initial))
        high = npv(discount_initial, calculate_fcfs(best, price_initial, cogs_initial))
    elif param == 'Sale Price':
        low = npv(discount_initial, calculate_fcfs(units_initial, worst, cogs_initial))
        high = npv(discount_initial, calculate_fcfs(units_initial, best, cogs_initial))
    elif param == 'Cost of Goods':
        low = npv(discount_initial, calculate_fcfs(units_initial, price_initial, worst))
        high = npv(discount_initial, calculate_fcfs(units_initial, price_initial, best))
    elif param == 'Cost of Capital':
        low = npv(worst, calculate_fcfs(units_initial, price_initial, cogs_initial))
        high = npv(best, calculate_fcfs(units_initial, price_initial, cogs_initial))
    
    npv_ranges[param] = [low, high]

# Prepare plot
labels = list(npv_ranges.keys())
lows = [npv_ranges[label][0]/1000 for label in labels]
highs = [npv_ranges[label][1]/1000 for label in labels]
base_million = base_npv / 1000

# Plot tornado diagram
fig, ax = plt.subplots(figsize=(10, 6))
for i, label in enumerate(labels):
    low = lows[i]
    high = highs[i]
    ax.barh(label, high - low, left=low, color='green' if high > low else 'red', alpha=0.6)
    ax.axvline(base_million, color='black', linestyle='--')

ax.set_xlabel('Project NPV ($ Millions)')
ax.set_title('Sensitivity Analysis - Tornado Diagram')
ax.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
npv_ranges, base_npv
# Out:
# ({'Units Sold': [-6919.819442559281, 21548.900615460392],
#   'Sale Price': [-17698.100287570844, 20377.348349698266],
#   'Cost of Goods': [-8325.682161473833, 12762.258622244442],
#   'Cost of Capital': [2255.9745658819766, 7088.988426026533]},
#  5732.945027671686)

# %% [markdown]
# ---

# %% [markdown]
# ### What is next?
#
# * Problem Set 4
# * *   Valuing Bonds
#     *   Reading(s):
#         *   CF-B&D: Ch. 6
#
# ---
